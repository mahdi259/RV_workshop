# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdi259/RV_workshop/blob/main/RISC_V_lab_Convert_NEORV32_VHDL_files_to_one_verilog_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Download GHDL**

# %%
# %cd /content
# !rm -r /content/ghdl
# !git clone https://github.com/ghdl/ghdl.git
# Out:
# /content
# rm: cannot remove '/content/ghdl': No such file or directory
# Cloning into 'ghdl'...
# remote: Enumerating objects: 82157, done.
# remote: Counting objects: 100% (7446/7446), done.
# remote: Compressing objects: 100% (1267/1267), done.
# remote: Total 82157 (delta 6538), reused 6841 (delta 6176), pack-reused 74711 (from 1)
# Receiving objects: 100% (82157/82157), 81.23 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (61787/61787), done.
# Updating files: 100% (12544/12544), done.

# %% [markdown]
# # **Install GHDL**

# %%
# %cd /content/ghdl
# !apt install gnat
# !./configure --prefix=/usr/local
# !make
# !make install
# Out:
# /content/ghdl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-10 gcc-10 gcc-10-base gnat-10 libgcc-10-dev libgnat-10 libgnat-util10
# Suggested packages:
#   gcc-10-locales gcc-10-multilib gcc-10-doc ada-reference-manual-2012 gnat-10-doc gnat-10-sjlj
# The following NEW packages will be installed:
#   cpp-10 gcc-10 gcc-10-base gnat gnat-10 libgcc-10-dev libgnat-10 libgnat-util10
# 0 upgraded, 8 newly installed, 0 to remove and 49 not upgraded.
# Need to get 49.6 MB of archives.
# After this operation, 175 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gcc-10-base amd64 10.5.0-1ubuntu1~22.04 [21.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 cpp-10 amd64 10.5.0-1ubuntu1~22.04 [9,395 kB]
# ...

# %% [markdown]
# # **Get NeoRV32 verilog**

# %% [markdown]
# - GHDL looks at neorv32-verilog/src/convert.sh file to know which modules are included in conversion and where the top module is located.
#
# - The current topmodule is neorv32-verilog/src/neorv32_verilog_wrapper.vhd that enables UART, timer and some other features.
#
# - You can change the top module in convert.sh and determine a small part of the system to be converted into verilog. (Keep in mind that neorv32_verilog_wrapper.vhd assignes some parameters of CPU and these parameters should have valid assignment if you want to convert any submodules.)

# %%
# %cd /content
# !rm -rf neorv32-verilog
# %cd /content
# !git clone --recursive https://github.com/stnolting/neorv32-verilog.git

# %%
# %cd /content/neorv32-verilog/src
# !sh convert.sh
# Out:
# /content/neorv32-verilog/src
# NEORV32 Version:
# 32:  constant hw_version_c : std_ulogic_vector(31 downto 0) := x"01100600"; -- hardware version
#
# ghdl:error: cannot open ./neorv32_top.vhd
